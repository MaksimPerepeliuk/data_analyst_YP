# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Описание-исследования" data-toc-modified-id="Описание-исследования-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Описание исследования</a></span></li><li><span><a href="#Задачи-исследования" data-toc-modified-id="Задачи-исследования-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Задачи исследования</a></span></li><li><span><a href="#Описание-данных" data-toc-modified-id="Описание-данных-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Описание данных</a></span></li><li><span><a href="#Предобработка-данных" data-toc-modified-id="Предобработка-данных-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Предобработка данных</a></span><ul class="toc-item"><li><span><a href="#Псмотрим-на-имеющиеся-данные" data-toc-modified-id="Псмотрим-на-имеющиеся-данные-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Псмотрим на имеющиеся данные</a></span></li><li><span><a href="#Посмотрим-нет-ли-скрытых-пробелов-или-других-ошибок-в-именовании-колонок" data-toc-modified-id="Посмотрим-нет-ли-скрытых-пробелов-или-других-ошибок-в-именовании-колонок-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Посмотрим нет ли скрытых пробелов или других ошибок в именовании колонок</a></span></li><li><span><a href="#Исследуем-пропущенные-значения" data-toc-modified-id="Исследуем-пропущенные-значения-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Исследуем пропущенные значения</a></span><ul class="toc-item"><li><span><a href="#Посмотрим-на-доли-пропущенных-значений-по-колонкам" data-toc-modified-id="Посмотрим-на-доли-пропущенных-значений-по-колонкам-4.3.1"><span class="toc-item-num">4.3.1&nbsp;&nbsp;</span>Посмотрим на доли пропущенных значений по колонкам</a></span></li><li><span><a href="#Найдем-общее-количество-пропусков" data-toc-modified-id="Найдем-общее-количество-пропусков-4.3.2"><span class="toc-item-num">4.3.2&nbsp;&nbsp;</span>Найдем общее количество пропусков</a></span></li></ul></li><li><span><a href="#Обработаем-пропуски" data-toc-modified-id="Обработаем-пропуски-4.4"><span class="toc-item-num">4.4&nbsp;&nbsp;</span>Обработаем пропуски</a></span><ul class="toc-item"><li><span><a href="#Колонка-balcony---наличие-балкона" data-toc-modified-id="Колонка-balcony---наличие-балкона-4.4.1"><span class="toc-item-num">4.4.1&nbsp;&nbsp;</span>Колонка <code>balcony</code> - наличие балкона</a></span></li><li><span><a href="#Колонка-is_apartment---является-ли-объект-недвижимости-апартаментами" data-toc-modified-id="Колонка-is_apartment---является-ли-объект-недвижимости-апартаментами-4.4.2"><span class="toc-item-num">4.4.2&nbsp;&nbsp;</span>Колонка <code>is_apartment</code> - является ли объект недвижимости апартаментами</a></span></li><li><span><a href="#Колонка-ceiling_height-высота-потолков" data-toc-modified-id="Колонка-ceiling_height-высота-потолков-4.4.3"><span class="toc-item-num">4.4.3&nbsp;&nbsp;</span>Колонка <code>ceiling_height</code> высота потолков</a></span></li><li><span><a href="#Колонка-floors_total-количество-этажей-в-доме" data-toc-modified-id="Колонка-floors_total-количество-этажей-в-доме-4.4.4"><span class="toc-item-num">4.4.4&nbsp;&nbsp;</span>Колонка <code>floors_total</code> количество этажей в доме</a></span></li><li><span><a href="#Колонки-living_area,-kitchen_area-площадь-жилой-зоны-и-кухни" data-toc-modified-id="Колонки-living_area,-kitchen_area-площадь-жилой-зоны-и-кухни-4.4.5"><span class="toc-item-num">4.4.5&nbsp;&nbsp;</span>Колонки <code>living_area</code>, <code>kitchen_area</code> площадь жилой зоны и кухни</a></span></li></ul></li><li><span><a href="#Исследуем-типы-данных-колонок" data-toc-modified-id="Исследуем-типы-данных-колонок-4.5"><span class="toc-item-num">4.5&nbsp;&nbsp;</span>Исследуем типы данных колонок</a></span></li><li><span><a href="#Добавим-новые-признаки" data-toc-modified-id="Добавим-новые-признаки-4.6"><span class="toc-item-num">4.6&nbsp;&nbsp;</span>Добавим новые признаки</a></span><ul class="toc-item"><li><span><a href="#Добавим-цену-квадратного-метра-для-каждой-квартиры:" data-toc-modified-id="Добавим-цену-квадратного-метра-для-каждой-квартиры:-4.6.1"><span class="toc-item-num">4.6.1&nbsp;&nbsp;</span>Добавим цену квадратного метра для каждой квартиры:</a></span></li><li><span><a href="#Добавим-колонки-с-днем-недели,-месяцем-и-годом:" data-toc-modified-id="Добавим-колонки-с-днем-недели,-месяцем-и-годом:-4.6.2"><span class="toc-item-num">4.6.2&nbsp;&nbsp;</span>Добавим колонки с днем недели, месяцем и годом:</a></span></li><li><span><a href="#Категоризуем-данные-по-этажам-квартиры;-варианты-—-первый,-последний,-другой:" data-toc-modified-id="Категоризуем-данные-по-этажам-квартиры;-варианты-—-первый,-последний,-другой:-4.6.3"><span class="toc-item-num">4.6.3&nbsp;&nbsp;</span>Категоризуем данные по этажам квартиры; варианты — первый, последний, другой:</a></span></li><li><span><a href="#Добавим-колонки-с-соотношениями-жилой-и-общей-площади,-а-также-отношение-площади-кухни-к-общей:" data-toc-modified-id="Добавим-колонки-с-соотношениями-жилой-и-общей-площади,-а-также-отношение-площади-кухни-к-общей:-4.6.4"><span class="toc-item-num">4.6.4&nbsp;&nbsp;</span>Добавим колонки с соотношениями жилой и общей площади, а также отношение площади кухни к общей:</a></span></li></ul></li></ul></li><li><span><a href="#Анализ-данных" data-toc-modified-id="Анализ-данных-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Анализ данных</a></span><ul class="toc-item"><li><span><a href="#Исследуем,-сколько-времени-требуется-на-продажу-квартиры" data-toc-modified-id="Исследуем,-сколько-времени-требуется-на-продажу-квартиры-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>Исследуем, сколько времени требуется на продажу квартиры</a></span></li><li><span><a href="#Исследуем-выбросы" data-toc-modified-id="Исследуем-выбросы-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>Исследуем выбросы</a></span><ul class="toc-item"><li><span><a href="#Посмотрим-на-распределения-признаков" data-toc-modified-id="Посмотрим-на-распределения-признаков-5.2.1"><span class="toc-item-num">5.2.1&nbsp;&nbsp;</span>Посмотрим на распределения признаков</a></span></li><li><span><a href="#Посмотрим-на-выбросы-в-колонке-days_exposition" data-toc-modified-id="Посмотрим-на-выбросы-в-колонке-days_exposition-5.2.2"><span class="toc-item-num">5.2.2&nbsp;&nbsp;</span>Посмотрим на выбросы в колонке <code>days_exposition</code></a></span></li><li><span><a href="#Построим-на-аномальные-значения-для-других-колонок" data-toc-modified-id="Построим-на-аномальные-значения-для-других-колонок-5.2.3"><span class="toc-item-num">5.2.3&nbsp;&nbsp;</span>Построим на аномальные значения для других колонок</a></span></li><li><span><a href="#Обработаем-выбросы" data-toc-modified-id="Обработаем-выбросы-5.2.4"><span class="toc-item-num">5.2.4&nbsp;&nbsp;</span>Обработаем выбросы</a></span></li></ul></li><li><span><a href="#Оценим-какие-параметры-больше-всего-влияют-на-цену-квартиры" data-toc-modified-id="Оценим-какие-параметры-больше-всего-влияют-на-цену-квартиры-5.3"><span class="toc-item-num">5.3&nbsp;&nbsp;</span>Оценим какие параметры больше всего влияют на цену квартиры</a></span><ul class="toc-item"><li><span><a href="#построим-матрицу-корреляций:" data-toc-modified-id="построим-матрицу-корреляций:-5.3.1"><span class="toc-item-num">5.3.1&nbsp;&nbsp;</span>построим матрицу корреляций:</a></span></li><li><span><a href="#Построим-матрицу-рассеяния-для-основных-колонок:" data-toc-modified-id="Построим-матрицу-рассеяния-для-основных-колонок:-5.3.2"><span class="toc-item-num">5.3.2&nbsp;&nbsp;</span>Построим матрицу рассеяния для основных колонок:</a></span></li><li><span><a href="#Создадим-функцию-для-построения-графиков-по-сгруппированным-значениям:" data-toc-modified-id="Создадим-функцию-для-построения-графиков-по-сгруппированным-значениям:-5.3.3"><span class="toc-item-num">5.3.3&nbsp;&nbsp;</span>Создадим функцию для построения графиков по сгруппированным значениям:</a></span></li><li><span><a href="#Построим-графики,-демонстрирующие-как-различные-парметры-влияют-на-цену:" data-toc-modified-id="Построим-графики,-демонстрирующие-как-различные-парметры-влияют-на-цену:-5.3.4"><span class="toc-item-num">5.3.4&nbsp;&nbsp;</span>Построим графики, демонстрирующие как различные парметры влияют на цену:</a></span></li></ul></li><li><span><a href="#Оценим-среднюю-цену-квадратного-метра-в-10-населенных-пунктах-с-самым-большим-количеством-объявлений:" data-toc-modified-id="Оценим-среднюю-цену-квадратного-метра-в-10-населенных-пунктах-с-самым-большим-количеством-объявлений:-5.4"><span class="toc-item-num">5.4&nbsp;&nbsp;</span>Оценим среднюю цену квадратного метра в 10 населенных пунктах с самым большим количеством объявлений:</a></span></li><li><span><a href="#Оценим-влияние-расстояния-до-центра-в-г.-Санкт-Петербург,-на-среднюю-стоимость-квадратного-метра-жилья" data-toc-modified-id="Оценим-влияние-расстояния-до-центра-в-г.-Санкт-Петербург,-на-среднюю-стоимость-квадратного-метра-жилья-5.5"><span class="toc-item-num">5.5&nbsp;&nbsp;</span>Оценим влияние расстояния до центра в г. Санкт-Петербург, на среднюю стоимость квадратного метра жилья</a></span></li><li><span><a href="#Проанализируем-сегмент-квартир-расположенных-в-центре-г.-Санкт-Петербург" data-toc-modified-id="Проанализируем-сегмент-квартир-расположенных-в-центре-г.-Санкт-Петербург-5.6"><span class="toc-item-num">5.6&nbsp;&nbsp;</span>Проанализируем сегмент квартир расположенных в центре г. Санкт-Петербург</a></span><ul class="toc-item"><li><span><a href="#Сравним-площадь,-стоимость,-количество-комнат-и-высоту-потолков-для-квартир-из-общего-набора-данных-и-для-квартир-в-центре-города:" data-toc-modified-id="Сравним-площадь,-стоимость,-количество-комнат-и-высоту-потолков-для-квартир-из-общего-набора-данных-и-для-квартир-в-центре-города:-5.6.1"><span class="toc-item-num">5.6.1&nbsp;&nbsp;</span>Сравним площадь, стоимость, количество комнат и высоту потолков для квартир из общего набора данных и для квартир в центре города:</a></span></li></ul></li><li><span><a href="#Посмотрим-какие-параметры-больше-всего-влияют-на-цену-квартиры-в-центре-г.-Санкт-Петербург" data-toc-modified-id="Посмотрим-какие-параметры-больше-всего-влияют-на-цену-квартиры-в-центре-г.-Санкт-Петербург-5.7"><span class="toc-item-num">5.7&nbsp;&nbsp;</span>Посмотрим какие параметры больше всего влияют на цену квартиры в центре г. Санкт-Петербург</a></span><ul class="toc-item"><li><span><a href="#Построим-графики,-демонстрирующие-как-различные-парметры-влияют-на-цену-для-жилья-в-центре-г.-Санкт-Петербург-в-сравнении-с-графиками-для-всех-квартир:" data-toc-modified-id="Построим-графики,-демонстрирующие-как-различные-парметры-влияют-на-цену-для-жилья-в-центре-г.-Санкт-Петербург-в-сравнении-с-графиками-для-всех-квартир:-5.7.1"><span class="toc-item-num">5.7.1&nbsp;&nbsp;</span>Построим графики, демонстрирующие как различные парметры влияют на цену для жилья в центре г. Санкт-Петербург в сравнении с графиками для всех квартир:</a></span></li></ul></li></ul></li><li><span><a href="#Общий-вывод" data-toc-modified-id="Общий-вывод-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Общий вывод</a></span></li></ul></div>

# %% [markdown]
# # Исследование объявлений о продаже квартир

# %% [markdown]
# ## Описание исследования
#
# В нашем распоряжении данные архива объявлений о продаже квартир в Санкт-Петербурге и соседних населённых пунктах за несколько лет.
#
# По каждой квартире на продажу доступны два вида данных: Первые вписаны пользователем, вторые — получены автоматически на основе картографических данных. Например, расстояние до центра, аэропорта, ближайшего парка и водоёма.

# %% [markdown]
# ## Задачи исследования
#
# - Выявить, какие признаки больше всего влияют на цену квартиры
# - Сравнить как отличаются признаки у квартир в зависимости от удаленности от центра г. Санкт-Петербург

# %% [markdown]
# ## Описание данных
# - airports_nearest — расстояние до ближайшего аэропорта в метрах (м)
# - balcony — число балконов
# - ceiling_height — высота потолков (м)
# - cityCenters_nearest — расстояние до центра города (м)
# - days_exposition — сколько дней было размещено объявление (от публикации до снятия)
# - first_day_exposition — дата публикации
# - floor — этаж
# - floors_total — всего этажей в доме
# - is_apartment — апартаменты (булев тип)
# - kitchen_area — площадь кухни в квадратных метрах (м²)
# - last_price — цена на момент снятия с публикации
# - living_area — жилая площадь в квадратных метрах (м²)
# - locality_name — название населённого пункта
# - open_plan — свободная планировка (булев тип)
# - parks_around3000 — число парков в радиусе 3 км
# - parks_nearest — расстояние до ближайшего парка (м)
# - ponds_around3000 — число водоёмов в радиусе 3 км
# - ponds_nearest — расстояние до ближайшего водоёма (м)
# - rooms — число комнат
# - studio — квартира-студия (булев тип)
# - total_area — площадь квартиры в квадратных метрах (м²)
# - total_images — число фотографий квартиры в объявлении

# %% [markdown]
# ## Предобработка данных

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import warnings

warnings.filterwarnings('ignore')
pd.set_option('display.float_format', '{:,.2f}'.format)

# %% [markdown]
# ### Псмотрим на имеющиеся данные

# %%
data = pd.read_csv('./real_estate_data.csv', sep='\t')
data.head()
# Out:
#    total_images    last_price  total_area first_day_exposition  rooms  \
# 0            20 13,000,000.00      108.00  2019-03-07T00:00:00      3
# 1             7  3,350,000.00       40.40  2018-12-04T00:00:00      1
# 2            10  5,196,000.00       56.00  2015-08-20T00:00:00      2
# 3             0 64,900,000.00      159.00  2015-07-24T00:00:00      3
# 4             2 10,000,000.00      100.00  2018-06-19T00:00:00      2
#
#    ceiling_height  floors_total  living_area  floor is_apartment  ...  \
# 0            2.70         16.00        51.00      8          NaN  ...
# 1             NaN         11.00        18.60      1          NaN  ...
# 2             NaN          5.00        34.30      4          NaN  ...
# 3             NaN         14.00          NaN      9          NaN  ...
# 4            3.03         14.00        32.00     13          NaN  ...
#
#    kitchen_area  balcony    locality_name  airports_nearest  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23699 entries, 0 to 23698
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23699 non-null  int64
#  1   last_price            23699 non-null  float64
#  2   total_area            23699 non-null  float64
#  3   first_day_exposition  23699 non-null  object
#  4   rooms                 23699 non-null  int64
#  5   ceiling_height        14504 non-null  float64
#  6   floors_total          23613 non-null  float64
#  7   living_area           21796 non-null  float64
#  8   floor                 23699 non-null  int64
#  9   is_apartment          2775 non-null   object
#  10  studio                23699 non-null  bool
#  11  open_plan             23699 non-null  bool
#  12  kitchen_area          21421 non-null  float64
#  13  balcony               12180 non-null  float64
#  14  locality_name         23650 non-null  object
# ...

# %%
data.describe()
# Out:
#        total_images     last_price  total_area     rooms  ceiling_height  \
# count     23,699.00      23,699.00   23,699.00 23,699.00       14,504.00
# mean           9.86   6,541,548.77       60.35      2.07            2.77
# std            5.68  10,887,013.27       35.65      1.08            1.26
# min            0.00      12,190.00       12.00      0.00            1.00
# 25%            6.00   3,400,000.00       40.00      1.00            2.52
# 50%            9.00   4,650,000.00       52.00      2.00            2.65
# 75%           14.00   6,800,000.00       69.90      3.00            2.80
# max           50.00 763,000,000.00      900.00     19.00          100.00
#
#        floors_total  living_area     floor  kitchen_area   balcony  \
# count     23,613.00    21,796.00 23,699.00     21,421.00 12,180.00
# mean          10.67        34.46      5.89         10.57      1.15
# std            6.60        22.03      4.89          5.91      1.07
# ...

# %% [markdown]
# Всего 23699 строк и 22 колонок. Бросается в глаза большое количество пропусков.

# %% [markdown]
# ### Посмотрим нет ли скрытых пробелов или других ошибок в именовании колонок

# %%
data.columns
# Out:
# Index(['total_images', 'last_price', 'total_area', 'first_day_exposition',
#        'rooms', 'ceiling_height', 'floors_total', 'living_area', 'floor',
#        'is_apartment', 'studio', 'open_plan', 'kitchen_area', 'balcony',
#        'locality_name', 'airports_nearest', 'cityCenters_nearest',
#        'parks_around3000', 'parks_nearest', 'ponds_around3000',
#        'ponds_nearest', 'days_exposition'],
#       dtype='object')

# %% [markdown]
# В имени колонки cityCenters_nearest использована верблюжья нотация. Переименуем в соответствии со змеиной нотацией:

# %%
data = data.rename(columns={'cityCenters_nearest': 'city_centers_nearest'})

# %% [markdown]
# Остальные колонки именованы корректно

# %% [markdown]
# ### Исследуем пропущенные значения

# %% [markdown]
# #### Посмотрим на доли пропущенных значений по колонкам

# %%
data.isna().mean().sort_values(ascending=False)
# Out:
# is_apartment           0.88
# parks_nearest          0.66
# ponds_nearest          0.62
# balcony                0.49
# ceiling_height         0.39
# airports_nearest       0.23
# city_centers_nearest   0.23
# ponds_around3000       0.23
# parks_around3000       0.23
# days_exposition        0.13
# kitchen_area           0.10
# living_area            0.08
# floors_total           0.00
# locality_name          0.00
# total_images           0.00
# last_price             0.00
# studio                 0.00
# floor                  0.00
# rooms                  0.00
# first_day_exposition   0.00
# total_area             0.00
# open_plan              0.00
# dtype: float64

# %% [markdown]
# #### Найдем общее количество пропусков

# %%
data.isna().sum().sum()
# Out:
# 101441

# %% [markdown]
# Всего 101441 пропущенное значение

# %%
nan_rows_number = data.isna().any(axis=1).sum()
nan_rows_number
# Out:
# 23449

# %% [markdown]
# 23449 строк с хотябы одним пропуском

# %%
(nan_rows_number / len(data)) * 100
# Out:
# 98.94510316891008

# %% [markdown]
# Почти в 99% строк присутствуют пропуски

# %% [markdown]
# ### Обработаем пропуски

# %% [markdown]
# #### Колонка `balcony` - наличие балкона

# %% [markdown]
# В колонке `balcony` пропущенные значения можно заменить на 0 т.к. в данном случае, отсутсвующее значение скорее всего означает, что балкона просто нет, во всяком случае примем такое допущение

# %%
data['balcony'] = data['balcony'].fillna(0)

# %%
data.isna().sum()
# Out:
# total_images                0
# last_price                  0
# total_area                  0
# first_day_exposition        0
# rooms                       0
# ceiling_height           9195
# floors_total               86
# living_area              1903
# floor                       0
# is_apartment            20924
# studio                      0
# open_plan                   0
# kitchen_area             2278
# balcony                     0
# locality_name              49
# airports_nearest         5542
# city_centers_nearest     5519
# parks_around3000         5518
# parks_nearest           15620
# ponds_around3000         5518
# ponds_nearest           14589
# days_exposition          3181
# dtype: int64

# %% [markdown]
# #### Колонка `is_apartment` - является ли объект недвижимости апартаментами
#
# Самое большое количество пропусков в колонке is_apartment, возможно пропуск означает, что человек просто не указал данный признак подразумевая, что по умолчанию статус объекта - квартира. Несмотря на то, что в данной колонке слишком много пропусков и эту колонку можно было бы просто удалить, статус апартаментов сильно влияет на цену недвижимости, поэтому можно взять среднюю цену для недвижимости со статусом апартаментов и сравнить это среднее со средним значением (или медианное) после заполнения пропусков значением True, если среднее не сильно изменится - тогда оставим зполнение, иначе удалим колонку.

# %% [markdown]
# Для начала построим гистограмму цен:

# %%
data.plot(kind='hist', y='last_price', ylabel='m', title='Частота цен на недвижимость')
plt.xlabel('Цена ₽')
plt.ylabel('Частота')
plt.show()

# %% [markdown]
# На гистограмме видно, что хвост распределения цен уходит вправо до 800 000 000. Масштабируем гистограмму от 0 до 20 000 000:

# %%
data.plot(kind='hist', y='last_price' , range=(0, 20000000), title='Частота цен на недвижимость от 0 до 20 000 000')
plt.xlabel('Цена ₽')
plt.ylabel('Частота')
plt.show()

# %% [markdown]
# Несмотря на большие выбросы, медиана выглядит близкой к реальным значениям цены.

# %% [markdown]
# Теперь заполним пропуски значением False и посмотрим как изменится медиана

# %%
(data.groupby('is_apartment')
    .agg({'last_price': ['median', 'count']}))
# Out:
#                last_price
#                    median count
# is_apartment
# False        4,700,000.00  2725
# True         6,900,000.00    50

# %% [markdown]
# Значения медианы цены до заполнения пропусков

# %%
test_df = data.copy()[['is_apartment', 'last_price']]
test_df['is_apartment'] = test_df['is_apartment'].fillna(False)
(test_df.groupby('is_apartment')
    .agg({'last_price': ['median', 'count']}))
# Out:
#                last_price
#                    median  count
# is_apartment
# False        4,644,000.00  23649
# True         6,900,000.00     50

# %% [markdown]
# Значения медианы цены после заполнения пропусков

# %% [markdown]
# Вывод:
# - Медиана после заполнения пропусков почти не изменилась, значит наше предположение о природе данных пропусков скорее всего верно.

# %% [markdown]
# Заполним пропуски

# %%
data['is_apartment'] = data['is_apartment'].fillna(False)

# %%
data.isna().sum()
# Out:
# total_images                0
# last_price                  0
# total_area                  0
# first_day_exposition        0
# rooms                       0
# ceiling_height           9195
# floors_total               86
# living_area              1903
# floor                       0
# is_apartment                0
# studio                      0
# open_plan                   0
# kitchen_area             2278
# balcony                     0
# locality_name              49
# airports_nearest         5542
# city_centers_nearest     5519
# parks_around3000         5518
# parks_nearest           15620
# ponds_around3000         5518
# ponds_nearest           14589
# days_exposition          3181
# dtype: int64

# %% [markdown]
# #### Колонка `ceiling_height` высота потолков

# %% [markdown]
# Много пропусков в колонке `ceiling_height`, если данная колонка сильно коррелирует с ценой, то есть смысл заполнить пропуски сгруппировав таблицу по цене (предварительно проведя категоризацию по цене). Для этого посмотрим зависимость высоты потолков от цены:

# %%
data['ceiling_height'].describe()
# Out:
# count   14,504.00
# mean         2.77
# std          1.26
# min          1.00
# 25%          2.52
# 50%          2.65
# 75%          2.80
# max        100.00
# Name: ceiling_height, dtype: float64

# %%
data.plot(
    kind='scatter', 
    x='last_price', 
    y='ceiling_height', 
    title='Зависимость высоты потолков от цены на объект недвижимости'
)
plt.xlabel('Цена ₽')
plt.ylabel('Высота потолков (м)')
plt.show()

# %% [markdown]
# На графике видны сильные выбросы - явно неадэкватные значения высоты потолков (вплоть до 100м), обрежем часть данных по высоте потолков до 10м и цене до 20 000 000:

# %%
(data[(data['ceiling_height'] < 10) & 
      (data['last_price'] < 2000000)].plot(
         kind='scatter', 
         x='last_price', 
         y='ceiling_height', 
         title='Зависимость высоты потолков от цены на объект недвижимости'
     )
)
plt.xlabel('Цена ₽')
plt.ylabel('Высота потолков (м)')
plt.show()

# %% [markdown]
# Большинство значений выстроилось в линию на значении 2.5м высоты потолка, что означает отсутствие зависимости между ценой и высотой потолков. Поэтому можно заполнить пропуски медианным значением высоты.

# %%
data['ceiling_height'] = data['ceiling_height'].fillna(data['ceiling_height'].median())

# %%
data.isna().sum()
# Out:
# total_images                0
# last_price                  0
# total_area                  0
# first_day_exposition        0
# rooms                       0
# ceiling_height              0
# floors_total               86
# living_area              1903
# floor                       0
# is_apartment                0
# studio                      0
# open_plan                   0
# kitchen_area             2278
# balcony                     0
# locality_name              49
# airports_nearest         5542
# city_centers_nearest     5519
# parks_around3000         5518
# parks_nearest           15620
# ponds_around3000         5518
# ponds_nearest           14589
# days_exposition          3181
# dtype: int64

# %% [markdown]
# Много пропусков так же присутствуют в колонках с расстояниями, но заполнить их корректными значениями не получиться, так как расстояние до какого-либо объекта имеет мало связи с техническими характеристиками недвижимости. Поэтому пропуски в данных колонках оставим без обработки.

# %% [markdown]
# #### Колонка `floors_total` количество этажей в доме

# %%
data['floors_total'].isna().mean()
# Out:
# 0.0036288450989493226

# %% [markdown]
# Доля пропусков очень маленькая, поэтому просто удалим строки с этими пропусками

# %%
data = data.dropna(subset=['floors_total'])

# %% [markdown]
# #### Колонки `living_area`, `kitchen_area` площадь жилой зоны и кухни

# %% [markdown]
# Так как `living_area` и `kitchen_area` сильно связаны с общей площадью, а общая площадь в свою очередь связана с количеством комнат, то можно заполнить пропуски в этих колонках медианными значениями данных сгруппированных по параметру количества комнат:

# %%
medians = (data.groupby('rooms')
           .agg({'living_area': 'median', 'kitchen_area': 'median'})
           .rename(columns={'living_area': 'median_living_area', 'kitchen_area': 'median_kitchen_area'}))

data = data.merge(medians, on=['rooms'])
data.loc[data['living_area'].isna(), 'living_area'] = data.loc[data['living_area'].isna(), 'median_living_area']
data.loc[data['kitchen_area'].isna(), 'kitchen_area'] = data.loc[data['kitchen_area'].isna(), 'median_kitchen_area']

# %%
data.isna().sum()
# Out:
# total_images                0
# last_price                  0
# total_area                  0
# first_day_exposition        0
# rooms                       0
# ceiling_height              0
# floors_total                0
# living_area                 0
# floor                       0
# is_apartment                0
# studio                      0
# open_plan                   0
# kitchen_area              194
# balcony                     0
# locality_name              48
# airports_nearest         5532
# city_centers_nearest     5509
# parks_around3000         5508
# parks_nearest           15568
# ponds_around3000         5508
# ponds_nearest           14552
# days_exposition          3172
# median_living_area          0
# median_kitchen_area       194
# dtype: int64

# %% [markdown]
# Некоторые пропуски в `kitchen_area` остались из-за того, что в строках, где значение количества комнат равно 0, kitchen_area в этих строках равно NaN (это может означать студию). Так как пропусков осталось мало, просто удалим их

# %%
data = data.dropna(subset=['kitchen_area'])

# %%
data.isna().sum()
# Out:
# total_images                0
# last_price                  0
# total_area                  0
# first_day_exposition        0
# rooms                       0
# ceiling_height              0
# floors_total                0
# living_area                 0
# floor                       0
# is_apartment                0
# studio                      0
# open_plan                   0
# kitchen_area                0
# balcony                     0
# locality_name              48
# airports_nearest         5455
# city_centers_nearest     5432
# parks_around3000         5431
# parks_nearest           15402
# ponds_around3000         5431
# ponds_nearest           14426
# days_exposition          3158
# median_living_area          0
# median_kitchen_area         0
# dtype: int64

# %% [markdown]
# Вывод:
#  - Пропуски могли образоваться из-за того, что форма для подачи объявления имеет необязательные поля для заполнения и пользователи эти поля игнорируют

# %% [markdown]
# ### Исследуем типы данных колонок

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 23419 entries, 0 to 23612
# Data columns (total 24 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23419 non-null  int64
#  1   last_price            23419 non-null  float64
#  2   total_area            23419 non-null  float64
#  3   first_day_exposition  23419 non-null  object
#  4   rooms                 23419 non-null  int64
#  5   ceiling_height        23419 non-null  float64
#  6   floors_total          23419 non-null  float64
#  7   living_area           23419 non-null  float64
#  8   floor                 23419 non-null  int64
#  9   is_apartment          23419 non-null  bool
#  10  studio                23419 non-null  bool
#  11  open_plan             23419 non-null  bool
#  12  kitchen_area          23419 non-null  float64
#  13  balcony               23419 non-null  float64
#  14  locality_name         23371 non-null  object
# ...

# %% [markdown]
# `first_day_exposition` имеет тип object, но содержит значения дат, изменим ее тип на datetime

# %%
data['first_day_exposition'] = pd.to_datetime(data['first_day_exposition'])

# %%
data['first_day_exposition'].head()
# Out:
# 0   2019-03-07
# 1   2015-07-24
# 2   2017-02-26
# 3   2017-11-23
# 4   2019-01-09
# Name: first_day_exposition, dtype: datetime64[ns]

# %% [markdown]
# Поменяем тип данных с float64 на int64 в колонке balcony , что правильней с точки зрения смысла т.к. количество балконов это всегда целое число

# %%
data['balcony'] = data['balcony'].astype(int)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 23419 entries, 0 to 23612
# Data columns (total 24 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23419 non-null  int64
#  1   last_price            23419 non-null  float64
#  2   total_area            23419 non-null  float64
#  3   first_day_exposition  23419 non-null  datetime64[ns]
#  4   rooms                 23419 non-null  int64
#  5   ceiling_height        23419 non-null  float64
#  6   floors_total          23419 non-null  float64
#  7   living_area           23419 non-null  float64
#  8   floor                 23419 non-null  int64
#  9   is_apartment          23419 non-null  bool
#  10  studio                23419 non-null  bool
#  11  open_plan             23419 non-null  bool
#  12  kitchen_area          23419 non-null  float64
#  13  balcony               23419 non-null  int64
# ...

# %% [markdown]
# в колонках `floors_total`, `balcony`, `parks_around3000`, `ponds_around3000`, `days_exposition`, по смыслу тоже должны быть целые числа, однако в этих колонках присутствуют значения NaN (пропуски), которые имеют тип float, поэтому и все колонки имеют тип float

# %% [markdown]
# ### Добавим новые признаки

# %% [markdown]
# #### Добавим цену квадратного метра для каждой квартиры:

# %%
data['square_meter_price'] = round(data['last_price'] / data['total_area'])

# %% [markdown]
# #### Добавим колонки с днем недели, месяцем и годом:

# %%
data['weekday'] = data['first_day_exposition'].dt.weekday
data['month'] = data['first_day_exposition'].dt.month
data['year'] = data['first_day_exposition'].dt.year

# %% [markdown]
# #### Категоризуем данные по этажам квартиры; варианты — первый, последний, другой:

# %%
def make_type_floor(row):
    floor = row['floor']
    floors_total = row['floors_total']
    
    if floor == floors_total:
        return 'последний'
    elif floor == 1:
        return 'первый'
    
    return 'другой'

data['type_floor'] = data.apply(make_type_floor, axis=1)

# %% [markdown]
# #### Добавим колонки с соотношениями жилой и общей площади, а также отношение площади кухни к общей:

# %%
data['living_to_total_area_ratio'] = data['living_area'] / data['total_area']
data['kitchen_to_total_area_ratio'] = data['kitchen_area'] / data['total_area']

# %%
data[['living_to_total_area_ratio', 'kitchen_to_total_area_ratio']].head()
# Out:
#    living_to_total_area_ratio  kitchen_to_total_area_ratio
# 0                        0.47                         0.23
# 1                        0.28                         0.06
# 2                        0.71                         0.11
# 3                        0.68                         0.11
# 4                        0.63                         0.10

# %% [markdown]
# ## Анализ данных

# %% [markdown]
# ### Исследуем, сколько времени требуется на продажу квартиры

# %%
data['days_exposition'].describe()
# Out:
# count   20,261.00
# mean       181.51
# std        220.05
# min          1.00
# 25%         45.00
# 50%         96.00
# 75%        232.00
# max      1,580.00
# Name: days_exposition, dtype: float64

# %%
data['days_exposition'].hist(bins=100)
plt.title('days_exposition frequency')
plt.xlabel('days')
plt.ylabel('frequency')
plt.show()

# %% [markdown]
# Среднее опубликованного объявления о продажи, до момента снятия - 180 дней, медиана 95 дней. Разница почти в два раза, из-за того, что у нас достаточно "тяжелый хвост" у распределения значений времени. Это значит, что есть множество квартир, объявления которых выставлены гораздо дольше, чем 95 дней. Например мы видим, что 25% всех объявлений были выставлены в течении более 232 дней, а максимальная продолжительность выставленного объявления имеет значение 1580 дней.

# %% [markdown]
# ### Исследуем выбросы

# %% [markdown]
# #### Посмотрим на распределения признаков

# %%
columns = ['total_area', 'last_price', 'rooms', 'ceiling_height']

plt.figure(figsize=(20, 5))
for i, column in enumerate(columns):
    data.plot(kind='hist', y=column, title=f'{column} frequency', ax=plt.subplot(1, len(columns), i+1))
    plt.xlabel(column)
plt.tight_layout()
plt.show()

# %% [markdown]
# На всех графиках видны сильные отклонения вправо (пложительное смещение), то есть есть самые частые значения в начале диапазона, а большие значения встречаются очень редко

# %% [markdown]
# #### Посмотрим на выбросы в колонке `days_exposition`

# %%
data.boxplot(column='days_exposition')
plt.ylabel('days')
plt.ylim(0, 800)
plt.show()

# %% [markdown]
# Начало аномальных значений для `days_exposition` начинается примерно с 500 дней

# %% [markdown]
# #### Построим на аномальные значения для других колонок

# %%
columns = [
    'total_area', 
    'last_price', 
    'rooms', 
    'ceiling_height', 
    'city_centers_nearest', 
    'days_exposition', 
    'living_to_total_area_ratio',
    'kitchen_to_total_area_ratio'
]

nested_columns = np.array_split(columns, 2) # сделали вложенный список с двумя списками по 4 элемента

def make_boxplots(columns):
    for i in range(len(nested_columns)):
        plt.figure(figsize=(20, 10))
        for j in range(len(nested_columns[i])):
            data.boxplot(
                column=nested_columns[i][j], 
                ax=plt.subplot(2, len(nested_columns[i]), j+1)
            )
        plt.show()

# %%
make_boxplots(nested_columns)

# %% [markdown]
# Во всех основных колонках есть большое количество выбросов

# %% [markdown]
# #### Обработаем выбросы

# %% [markdown]
# Напишем функцию, которая очистит значения, находящиеся за пределами Q1 - 1.5IQR и Q3 + 1.5IQR

# %%
def clear_deviations(columns, data):
    cleared_data = pd.DataFrame() 
    for column in data.columns:
        # если колонки нет в переданном списке, оставляем без изм
        if column not in columns:
            cleared_data[column] = data[column]
        # иначе очищаям выбросы
        else:
            q1 = data[column].quantile(q=0.25)
            q3 = data[column].quantile(q=0.75)
            iqr = q3 - q1
            part_data = data[(data[column] < q3 + (1.5 * iqr)) &
                             (data[column] > q1 - (1.5 * iqr))]
            cleared_data[column] = part_data[column]
    return cleared_data

data = clear_deviations(columns, data)

# %% [markdown]
# Посмотрим как изменились графики boxplot:

# %%
make_boxplots(columns)

# %% [markdown]
# На графиках выбросов стало гораздо меньше, но они остались из за того, что изменились значения q1, q3 в самих колонках

# %% [markdown]
# ### Оценим какие параметры больше всего влияют на цену квартиры

# %% [markdown]
# #### построим матрицу корреляций:

# %%
data.corr()['last_price'].sort_values(ascending=False)
# Out:
# last_price                     1.00
# total_area                     0.69
# square_meter_price             0.62
# living_area                    0.56
# kitchen_area                   0.46
# rooms                          0.44
# median_living_area             0.44
# median_kitchen_area            0.26
# ceiling_height                 0.25
# floors_total                   0.20
# total_images                   0.16
# ponds_around3000               0.15
# floor                          0.13
# parks_around3000               0.12
# balcony                        0.07
# days_exposition                0.05
# parks_nearest                  0.03
# is_apartment                   0.02
# living_to_total_area_ratio     0.01
# month                          0.01
# year                          -0.00
# open_plan                     -0.00
# weekday                       -0.01
# studio                        -0.02
# airports_nearest              -0.04
# ponds_nearest                 -0.05
# ...

# %% [markdown]
# Самая сильная линейная связь с ценой квартиры у колонки общей площади квартиры (не считая цену за квадратный метр т.к. это само собой), в отрицательную сторону сильнее всего влияет удаленность от центра города.

# %% [markdown]
# #### Построим матрицу рассеяния для основных колонок:

# %%
pd.plotting.scatter_matrix(
    data[['last_price', 'total_area', 'rooms', 
          'city_centers_nearest']], figsize=(9, 9))
plt.show()

# %% [markdown]
# На графиках видна положительная корреляция между ценой и общей площадью.

# %% [markdown]
# #### Создадим функцию для построения графиков по сгруппированным значениям:

# %%
def make_plot_from_grouped(data, index, aggfunc, values, **kwargs):
    grouped_data = data.pivot_table(index=index, values=values, aggfunc=aggfunc)
    grouped_data = grouped_data.reset_index()
    grouped_data.columns = kwargs['x'], kwargs['y']
    ax = grouped_data.plot(**kwargs)
    return ax

# %% [markdown]
# #### Построим графики, демонстрирующие как различные парметры влияют на цену:

# %%
columns_for_plots = np.array_split(['type_floor', 'rooms', 'weekday', 'month', 'year'], 2)

for i in range(len(columns_for_plots)):
    for j in range(len(columns_for_plots[i])):
        make_plot_from_grouped(
            data=data,
            index=columns_for_plots[i][j],
            aggfunc=['median'],
            values='last_price',
            kind='bar',
            x=column,
            y='median_price',
            figsize=(30, 15),
            ax=plt.subplot(len(columns_for_plots), len(columns_for_plots[i]), j+1)
        )
        plt.title(f'Зависимость медианной цены от {columns_for_plots[i][j]}', {'fontsize': 18})
        plt.ylabel('Цена ₽', {'fontsize': 18})
        plt.xlabel(columns_for_plots[i][j], {'fontsize': 18})
    plt.show()

# %% [markdown]
# __Выводы по графикам:__
#
# - первый и последний этажи самые дешевые;
# - видна сильная зависимость - чем больше комнат тем больше цена;
# - между днем недели и ценой видимые закономерности отсутствуют;
# - между месяцем и ценой видна взаимосвязь - цена плавно повышается с начала года и достигает пика в апреле, потом идет спад, минимум которого в июне и далее опять плавное повышение. Однако вообщем данная зависимость несущественно влияет на цену;
# - в зависимости от года - видно существенное снижение медианных цен с 2014 до 2016, далее идет рост.

# %% [markdown]
# ### Оценим среднюю цену квадратного метра в 10 населенных пунктах с самым большим количеством объявлений:

# %%
many_ads_local = data.pivot_table(
    index='locality_name', 
    values='square_meter_price', 
    aggfunc=['mean', 'count']
).reset_index()
many_ads_local.columns = ['locality_name', 'square_meter_mean_price', 'count']
many_ads_local = many_ads_local.sort_values(by='count', ascending=False).head(10)

# %%
many_ads_local.sort_values(by='square_meter_mean_price', ascending=False)
# Out:
#          locality_name  square_meter_mean_price  count
# 33     Санкт-Петербург               114,807.90  15542
# 32              Пушкин               103,125.82    369
# 93     деревня Кудрово                92,297.26    283
# 295  посёлок Парголово                90,289.76    323
# 290     посёлок Мурино                85,036.64    494
# 324     посёлок Шушары                78,277.95    435
# 13             Колпино                75,424.57    338
# 6              Гатчина                68,746.11    307
# 3           Всеволожск                68,618.02    392
# 4               Выборг                58,141.92    237

# %% [markdown]
# Построим столбчатый график, для наглядной демонстрации средней цены за квадратный метр:

# %%
(many_ads_local.sort_values(by='square_meter_mean_price', ascending=False)
               .plot(kind='bar', 
                     x='locality_name',
                     y='square_meter_mean_price', 
                     figsize=(10,7)))
plt.show()

# %% [markdown]
# Ожидаемо самая высокая стоимость квадратного метра жилья в г. Санкт-Петербург, самая низкая из популярных в объявлениях населенных пунктов г. Выборг.

# %% [markdown]
# ### Оценим влияние расстояния до центра в г. Санкт-Петербург, на среднюю стоимость квадратного метра жилья

# %% [markdown]
# Сделаем срез данных для г. Санкт-Петербург, переведем расстояние из метров в километры и округлим:

# %%
piter_data = data[data['locality_name'] == 'Санкт-Петербург']
piter_data['distance_to_center'] = round(piter_data['city_centers_nearest'] / 1000)

# %% [markdown]
# Построим диаграмму рассеяния, для визуализации связи между расстоянием до центра и средней ценой квадратного метра

# %%
make_plot_from_grouped(
    data=piter_data,
    index='distance_to_center',
    aggfunc=['mean'],
    values='square_meter_price',  
    x='distance_to_center',
    y='mean_price',
    kind='scatter',
    figsize=(10, 7)
)

plt.title('Зависимость цены от расстояния до центра города')
plt.xlabel('Дистанция до центра (км)')
plt.ylabel('Средняя цена $m^2$(₽)')
plt.show()

# %% [markdown]
# На графике видно точку где цена резко падает, на значении примерно в 6-7км, эту зону можно считать границей центра города.

# %% [markdown]
# ### Проанализируем сегмент квартир расположенных в центре г. Санкт-Петербург

# %% [markdown]
# Сделаем срез данных на основе выявленного расстояния которое будем считать центром города

# %%
central_apartments = piter_data[piter_data['distance_to_center'] < 7]

# %%
len(central_apartments)
# Out:
# 3083

# %% [markdown]
# Получилось 3083 квартиры в центре.

# %% [markdown]
# #### Сравним площадь, стоимость, количество комнат и высоту потолков для квартир из общего набора данных и для квартир в центре города:

# %%
data[['total_area', 'last_price', 'rooms', 'ceiling_height']].mean()
# Out:
# total_area              54.59
# last_price       4,854,031.48
# rooms                    2.05
# ceiling_height           2.63
# dtype: float64

# %%
central_apartments[['total_area', 'last_price', 'rooms', 'ceiling_height']].mean()
# Out:
# total_area              70.55
# last_price       7,566,158.18
# rooms                    2.69
# ceiling_height           2.67
# dtype: float64

# %% [markdown]
# Средние значения для квартир в центре гораздо больше, кроме средней высоты потолков, которые отличаются незначительно.

# %% [markdown]
# ### Посмотрим какие параметры больше всего влияют на цену квартиры в центре г. Санкт-Петербург

# %%
central_apartments.corr()['last_price'].sort_values(ascending=False)
# Out:
# last_price                     1.00
# total_area                     0.68
# living_area                    0.56
# rooms                          0.46
# median_living_area             0.44
# kitchen_area                   0.37
# median_kitchen_area            0.31
# square_meter_price             0.15
# floor                          0.12
# days_exposition                0.12
# ceiling_height                 0.10
# floors_total                   0.09
# total_images                   0.09
# balcony                        0.08
# ponds_nearest                  0.05
# living_to_total_area_ratio     0.04
# parks_nearest                  0.04
# parks_around3000               0.04
# weekday                        0.02
# year                          -0.00
# airports_nearest              -0.01
# open_plan                     -0.02
# month                         -0.02
# is_apartment                  -0.03
# ponds_around3000              -0.03
# studio                        -0.03
# ...

# %% [markdown]
#  Параметры коррелирующие с ценой, те же, что и у общих данных.

# %% [markdown]
# #### Построим графики, демонстрирующие как различные парметры влияют на цену для жилья в центре г. Санкт-Петербург в сравнении с графиками для всех квартир:

# %%
for i in range(len(columns_for_plots)):
    plt.figure(figsize=(30, 20))
    for j in range(len(columns_for_plots[i])):
        column = columns_for_plots[i][j]
        ax = make_plot_from_grouped(
            data=central_apartments,
            index=column,
            aggfunc=['median'],
            values='last_price',
            kind='bar',
            x=column,
            y='median_price',
            width=0.75,
            label='central_apartments',
            ax=plt.subplot(len(columns_for_plots), len(columns_for_plots[i]), j+1)
        )

        make_plot_from_grouped(
            data=data,
            index=column,
            aggfunc=['median'],
            values='last_price',
            kind='bar',
            x=column,
            y='median_price',
            width=0.5,
            color='lightgreen',
            label='all_apartments',
            ax=ax
        )
        plt.ylabel('median price (₽)', fontsize=18)
        plt.xlabel(column, fontsize=18)
        plt.title(f'median price to {column} dependence', fontsize=18)
        plt.legend(prop={"size":18})
    plt.show()

# %% [markdown]
# __Выводы по графиками для квартир в центре г. Санкт-Петербург:__
#
# - первый этаж дешевле остальных, как для квартир в центра, так и для остальных квартир
# - Для квартир в центре, последний этаж не отличается по цене от других этажей, в отличии от квартир находящихся вне центра;
# - Чем больше комнат тем больше цена;
# - между днем недели и ценой видимые закономерности отсутствуют, как и в похожем графике для общих данных;
# - между месяцем и ценой для квартир в центре особой взаимосвязи не наблюдается, есть два больших пика на 5 и 9 месяце, после пиков идет резкое падение к прошлым значениям до пиков;
# - в период с 2014 по 2019 годы цена на квартиры вне центра снизилась, а для квартир в центре наоборот выросла, при чем сещественно (с 6 до 8 млн)

# %% [markdown]
# ## Общий вывод

# %% [markdown]
#  - среднее время продажи квартиры 180 дней, продажа квартиры дольше чем 500 дней считается аномально долгой;
#  - самое большое влияние на цену квартиры оказывает общая ее площадь и удаленность от центра города;
#  - в общем случае цена квартир расположенных на первом и последнем этаже ниже остальных;
#  - цена на первом этаже для квартир в центре г. Санкт-Петербург ниже остальных, а цена квартир на последих этажах не отличается;
#  - цена студий в центре г. Санкт-Петербург на уровне трехкомнатных квартир, цена студий для всех объявлений - ниже квартир с другой планировкой;
#  - самая большая цена, с большим отраывом, наблюдается у квартир с удаленностью не более 2 км от центра г. Санкт-Петербург;
#  - самое большое влияние на цену оказывает общая площадь.
#  - в период с 2014 по 2019 годы цена на квартиры вне центра снизилась, а для квартир в центре наоборот выросла.
