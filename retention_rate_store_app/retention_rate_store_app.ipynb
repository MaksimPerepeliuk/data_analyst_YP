# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Задачи-исследования" data-toc-modified-id="Задачи-исследования-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Задачи исследования</a></span></li><li><span><a href="#Исходные-данные" data-toc-modified-id="Исходные-данные-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Исходные данные</a></span></li><li><span><a href="#Предобработка-данных" data-toc-modified-id="Предобработка-данных-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Предобработка данных</a></span><ul class="toc-item"><li><span><a href="#Исследуем-общую-информацию-о-данных" data-toc-modified-id="Исследуем-общую-информацию-о-данных-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Исследуем общую информацию о данных</a></span></li></ul></li><li><span><a href="#Исследовательский-анализ" data-toc-modified-id="Исследовательский-анализ-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Исследовательский анализ</a></span><ul class="toc-item"><li><span><a href="#Изучим-переменную-с-датами-регистраций-reg_date" data-toc-modified-id="Изучим-переменную-с-датами-регистраций-reg_date-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Изучим переменную с датами регистраций <code>reg_date</code></a></span><ul class="toc-item"><li><span><a href="#Посмотрим-на-период-регистраций-пользователей" data-toc-modified-id="Посмотрим-на-период-регистраций-пользователей-4.1.1"><span class="toc-item-num">4.1.1&nbsp;&nbsp;</span>Посмотрим на период регистраций пользователей</a></span></li><li><span><a href="#Динамика-изменения-количества-новых-пользователей-по-годам" data-toc-modified-id="Динамика-изменения-количества-новых-пользователей-по-годам-4.1.2"><span class="toc-item-num">4.1.2&nbsp;&nbsp;</span>Динамика изменения количества новых пользователей по годам</a></span></li><li><span><a href="#Динамика-изменения-количества-новых-пользователей-по-месяцам" data-toc-modified-id="Динамика-изменения-количества-новых-пользователей-по-месяцам-4.1.3"><span class="toc-item-num">4.1.3&nbsp;&nbsp;</span>Динамика изменения количества новых пользователей по месяцам</a></span></li><li><span><a href="#Относительный-прирост-новых-пользователей-по-месяцам" data-toc-modified-id="Относительный-прирост-новых-пользователей-по-месяцам-4.1.4"><span class="toc-item-num">4.1.4&nbsp;&nbsp;</span>Относительный прирост новых пользователей по месяцам</a></span></li></ul></li><li><span><a href="#Изучим-переменную-с-датами-транзакций-transaction_date" data-toc-modified-id="Изучим-переменную-с-датами-транзакций-transaction_date-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Изучим переменную с датами транзакций <code>transaction_date</code></a></span><ul class="toc-item"><li><span><a href="#Посмотрим-на-период-заказов" data-toc-modified-id="Посмотрим-на-период-заказов-4.2.1"><span class="toc-item-num">4.2.1&nbsp;&nbsp;</span>Посмотрим на период заказов</a></span></li><li><span><a href="#Динамика-изменения-количества-ордеров-по-месяцам" data-toc-modified-id="Динамика-изменения-количества-ордеров-по-месяцам-4.2.2"><span class="toc-item-num">4.2.2&nbsp;&nbsp;</span>Динамика изменения количества ордеров по месяцам</a></span></li><li><span><a href="#Посмотрим-на-динамику-относительного-изменения-количества-заказов-по-месяцам" data-toc-modified-id="Посмотрим-на-динамику-относительного-изменения-количества-заказов-по-месяцам-4.2.3"><span class="toc-item-num">4.2.3&nbsp;&nbsp;</span>Посмотрим на динамику относительного изменения количества заказов по месяцам</a></span></li><li><span><a href="#Посмотрим-на-распределение-количества-транзакций-по-пользователям" data-toc-modified-id="Посмотрим-на-распределение-количества-транзакций-по-пользователям-4.2.4"><span class="toc-item-num">4.2.4&nbsp;&nbsp;</span>Посмотрим на распределение количества транзакций по пользователям</a></span></li></ul></li></ul></li><li><span><a href="#Когортный-анализ" data-toc-modified-id="Когортный-анализ-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Когортный анализ</a></span><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#Создадим-сводную-таблицу-с-когортами-и-их-лайфтаймом" data-toc-modified-id="Создадим-сводную-таблицу-с-когортами-и-их-лайфтаймом-5.0.1"><span class="toc-item-num">5.0.1&nbsp;&nbsp;</span>Создадим сводную таблицу с когортами и их лайфтаймом</a></span></li><li><span><a href="#Сделаем-срез-данных-на-основе-горизонта-анализа" data-toc-modified-id="Сделаем-срез-данных-на-основе-горизонта-анализа-5.0.2"><span class="toc-item-num">5.0.2&nbsp;&nbsp;</span>Сделаем срез данных на основе горизонта анализа</a></span></li><li><span><a href="#Построим-тепловую-карту" data-toc-modified-id="Построим-тепловую-карту-5.0.3"><span class="toc-item-num">5.0.3&nbsp;&nbsp;</span>Построим тепловую карту</a></span></li><li><span><a href="#Посмотрим-динамику-изменения-retention-на-линейном-графике" data-toc-modified-id="Посмотрим-динамику-изменения-retention-на-линейном-графике-5.0.4"><span class="toc-item-num">5.0.4&nbsp;&nbsp;</span>Посмотрим динамику изменения retention на линейном графике</a></span></li></ul></li></ul></li><li><span><a href="#Выводы" data-toc-modified-id="Выводы-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Выводы</a></span></li></ul></div>

# %% [markdown]
# # Анализ коэффициента удержания в приложении покупок магазина

# %% [markdown]
# В июле 2015 года провели специальную акцию, направленную на улучшение ретеншена. Новым юзерам слали письмо с купоном на скидку.

# %% [markdown]
# ## Задачи исследования
#
# - Выяснить, сработала ли акция?
# - Как повел себя коэффициент удержания после проведения акции?

# %% [markdown]
# ## Исходные данные

# %% [markdown]
# - `user_id` - идентификатор пользвателя
# - `order_id` - идентификатор заказа
# - `reg_date` - дата регистрации пользователя
# - `transaction_date` - дата оформления заказа
# - `revenue` - выручка заказа

# %% [markdown]
# ## Предобработка данных

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

warnings.simplefilter(action='ignore', category=FutureWarning)

# %% [markdown]
# ### Исследуем общую информацию о данных

# %%
data = pd.read_csv('./analyst_test_transactions_db.csv')

# %%
data.head()
# Out:
#    user_id  order_id    reg_date transaction_date  revenue
# 0    57562   94545.0  2013-12-22       2015-07-16     1088
# 1    40047   81824.0  2013-11-24       2015-01-19     1027
# 2    48153  144851.0  2015-07-03       2015-10-29      601
# 3    54591  116111.0  2013-07-12       2015-04-30      881
# 4    39789  134943.0  2013-05-25       2015-07-21      984

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 76857 entries, 0 to 76856
# Data columns (total 5 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   user_id           76857 non-null  int64
#  1   order_id          76857 non-null  float64
#  2   reg_date          76857 non-null  object
#  3   transaction_date  76857 non-null  object
#  4   revenue           76857 non-null  int64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 2.9+ MB

# %% [markdown]
# Пропуски отсутствуют, именование колонок корректно. Изменим тип данных в колонках с датами на `datetime`

# %%
data['reg_date'] = pd.to_datetime(data['reg_date'])
data['transaction_date'] = pd.to_datetime(data['transaction_date'])

# %% [markdown]
# Посмотрим на наличие дубликатов

# %%
data.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Дубликаты отсутствуют

# %% [markdown]
# ## Исследовательский анализ

# %% [markdown]
# ### Изучим переменную с датами регистраций `reg_date`

# %% [markdown]
# #### Посмотрим на период регистраций пользователей

# %%
data[['reg_date']].agg(['min', 'max'])
# Out:
#       reg_date
# min 1900-01-01
# max 2015-11-20

# %% [markdown]
# Дата начала периода регистраций явно неккоректна. Посмотрим на другие значения дат в начале периода

# %%
data.groupby('reg_date').agg({'user_id': 'count'}).reset_index().sort_values(by='reg_date').head()
# Out:
#     reg_date  user_id
# 0 1900-01-01       53
# 1 2012-02-24        2
# 2 2012-02-27        3
# 3 2012-02-29        4
# 4 2012-03-01       25

# %% [markdown]
# Видно, что присутствует только одна неккоректная дата, которая имеется у 53 наблюдений в наших данных. Так как наблюдений немного, просто удалим их

# %%
data = data[data['reg_date'] >= '2012-02-24']

# %% [markdown]
# Теперь посмотрим на период регистрации пользователей только с корректными значениями

# %%
data[['reg_date']].agg(['min', 'max'])
# Out:
#       reg_date
# min 2012-02-24
# max 2015-11-20

# %%
print(data['reg_date'].max() - data['reg_date'].min())
# Out:
# 1365 days 00:00:00

# %% [markdown]
# Пользователи в наших данных регистрировались начиная с 2012 и заканчивая концом 2015 года.

# %% [markdown]
# #### Динамика изменения количества новых пользователей по годам

# %%
data['reg_year'] = data['reg_date'].astype('datetime64[Y]')

# %%
data.groupby('reg_year').agg({'user_id': 'nunique'}).plot(figsize=(7, 5), grid=True)
plt.title('Динамика регистраций новых пользователей по годам')
plt.show()

# %% [markdown]
# - Начиная с 2014 года прирост новых пользователей несколько уменьшился, по сравнению с предыдущими годами

# %% [markdown]
# #### Динамика изменения количества новых пользователей по месяцам

# %%
data['reg_month'] = data['reg_date'].astype('datetime64[M]')

# %%
data.groupby('reg_month').agg({'user_id': 'nunique'}).plot(figsize=(15, 7), grid=True)
plt.title('Динамика регистраций новых пользователей по месяцам')
plt.show()

# %% [markdown]
# Прирост новых пользователей в 2015 году очень волатилен и под конец наблюдается аномально резкое падение количества регистраций

# %% [markdown]
# #### Относительный прирост новых пользователей по месяцам

# %% [markdown]
# Посмотрим на прирост новых пользователей по месяцам, относительно общего прироста за соответсвующий год

# %%
data['reg_month_n'] = data['reg_date'].dt.month

users_by_years = data.groupby('reg_year').agg(
    users_by_year=('user_id', 'nunique')).reset_index()

users_by_months = (
    data.groupby(['reg_year', 'reg_month'])
        .agg(users_by_month=('user_id', 'nunique'))
        .reset_index()
)

users_by_months = users_by_months.merge(users_by_years, how='left', on='reg_year')
users_by_months['month_proportion'] = users_by_months['users_by_month'] / users_by_months['users_by_year']

# %% [markdown]
# Объединили две таблицы с данными количества регистраций по годам и месяцам и рассчитали долю регистраций в каждый месяц за соответсвующий год. Теперь построим линейный график

# %%
users_by_months[['reg_month', 'month_proportion']].plot(
    x='reg_month', 
    y='month_proportion',
    figsize=(10, 7),
    grid=True
)
plt.title('Динамика изменения доли прироста новых пользователей по месяцам')
plt.show()

# %% [markdown]
# На графике особой сезонности в целевой период с июля по конец каждого года не наблюдается

# %% [markdown]
# ### Изучим переменную с датами транзакций `transaction_date`

# %% [markdown]
# #### Посмотрим на период заказов

# %%
data[['transaction_date']].agg(['min', 'max'])
# Out:
#     transaction_date
# min       2015-01-01
# max       2015-11-20

# %%
print(data['transaction_date'].max() - data['transaction_date'].min())
# Out:
# 323 days 00:00:00

# %% [markdown]
# Всего имеем заказы за 323 дня, с начала 2015 года

# %% [markdown]
# #### Динамика изменения количества ордеров по месяцам

# %%
data['transaction_month'] = data['transaction_date'].astype('datetime64[M]')

# %%
data.groupby('transaction_month').agg({'user_id': ['count', 'nunique']}).plot(figsize=(15, 7), grid=True)
plt.legend(['Общее количество заказов', 'Заказы уникальных пользователей'])
plt.title('Динамика заказов по месяцам')
plt.show()

# %% [markdown]
# - В октябре количество заказов достигает максимума, затем резкое падение на уровень июля
# - Бросается в глаза, что заказы уникальных пользователей не намного меньше, чем все заказы за месяц.

# %% [markdown]
# #### Посмотрим на динамику относительного изменения количества заказов по месяцам

# %%
orders_by_years = data.groupby('reg_year').agg(
    orders_by_year=('order_id', 'count')).reset_index()

orders_by_months = (
    data.groupby(['reg_year', 'reg_month'])
        .agg(orders_by_month=('order_id', 'count'))
        .reset_index()
)

orders_by_months = orders_by_months.merge(orders_by_years, how='left', on='reg_year')
orders_by_months['month_proportion'] = orders_by_months['orders_by_month'] / orders_by_months['orders_by_year']

# %%
orders_by_months[['reg_month', 'month_proportion']].plot(
    x='reg_month', 
    y='month_proportion',
    figsize=(10, 7),
    grid=True
)
plt.title('Динамика изменения доли прироста новых пользователей по месяцам')
plt.show()

# %% [markdown]
# Данный график практически идетичен графику относительного прироста новых пользователей

# %% [markdown]
# #### Посмотрим на распределение количества транзакций по пользователям

# %%
orders_by_user = data.groupby('user_id')[['order_id']].count()

# %%
orders_by_user['order_id'].hist()
plt.title('Распределение количества заказов по пользователям')
plt.show()

# %%
orders_by_user.agg(['mean', 'median'])
# Out:
#         order_id
# mean    1.593708
# median  1.000000

# %% [markdown]
# Среднее количество заказов на одного пользователя больше медианы, что придает графику "тяжелый хвост"

# %% [markdown]
# ## Когортный анализ

# %% [markdown]
# Наша задача выяснить увеличился ли коэффициент удержания в связи с проведением акции в июле для новых пользователей. Для этого проведем когортный анализ, где когортами у нас будут пользователи зарегистрировавшиеся в каждый месяц 2015 года, а время жизни - лайфтайм будет измеряться в неделях

# %% [markdown]
# #### Создадим сводную таблицу с когортами и их лайфтаймом

# %%
data = data[data['reg_date'] >= '2015-01-01']

# %% [markdown]
# Сделали срез пользователей которые зарегистрировались в 2015 году, так как у нас имеются данные только для заказов сделанных в этом году

# %%
data['lifetime'] = (data['transaction_date'].dt.to_period('W').astype('int') - 
                    data['reg_date'].dt.to_period('W').astype('int'))

# %% [markdown]
# Выделили лайфтайм в неделях

# %%
data.head()
# Out:
#     user_id  order_id   reg_date transaction_date  revenue   reg_year  \
# 2     48153  144851.0 2015-07-03       2015-10-29      601 2015-01-01
# 5     72102   84827.0 2015-08-09       2015-11-18      946 2015-01-01
# 9     61469   54728.0 2015-07-27       2015-11-02      872 2015-01-01
# 11    55963  114131.0 2015-07-11       2015-08-26     1004 2015-01-01
# 12    42432  129397.0 2015-06-29       2015-09-20      442 2015-01-01
#
#     reg_month  reg_month_n transaction_month  lifetime
# 2  2015-07-01            7        2015-10-01        17
# 5  2015-08-01            8        2015-11-01        15
# 9  2015-07-01            7        2015-11-01        14
# 11 2015-07-01            7        2015-08-01         7
# 12 2015-06-01            6        2015-09-01        11

# %% [markdown]
# Теперь создадим сводную таблицу, где
# - индексы - это наши когорты по месяцу регистрации в 2015 году
# - колонки - это лайфтайм в неделях
# - значения - это количество уникальных пользователей по когортам и на определенный лайфтайм

# %%
retention = data.pivot_table(
    index='reg_month',
    columns='lifetime',
    values='user_id',
    aggfunc='nunique'
)

retention = retention.rename(columns={0: 'cohort_size'})
retention
# Out:
# lifetime    cohort_size      1      2      3      4      5      6      7  \
# reg_month
# 2015-01-01        294.0  174.0   92.0  102.0  110.0  107.0   96.0  124.0
# 2015-02-01        316.0  151.0  113.0  109.0  117.0  102.0   89.0   87.0
# 2015-03-01        362.0  173.0  106.0  120.0  114.0  120.0  111.0   88.0
# 2015-04-01        383.0  173.0  136.0  117.0  114.0  115.0  111.0   93.0
# 2015-05-01        381.0  162.0  143.0  102.0   98.0  102.0   99.0   89.0
# 2015-06-01        568.0  282.0  190.0  166.0  152.0  148.0  131.0  143.0
# 2015-07-01        644.0  391.0  341.0  320.0  283.0  276.0  248.0  234.0
# 2015-08-01        706.0  415.0  303.0  247.0  205.0  170.0  164.0  150.0
# 2015-09-01        618.0  298.0  217.0  205.0  186.0  197.0  182.0  172.0
# 2015-10-01        730.0  392.0  368.0  297.0  216.0  140.0   66.0   22.0
# 2015-11-01        574.0  234.0   83.0   10.0    NaN    NaN    NaN    NaN
#
# lifetime        8      9  ...    37    38    39    40    41    42    43    44  \
# ...

# %% [markdown]
# #### Сделаем срез данных на основе горизонта анализа

# %% [markdown]
# Рассчитаем горизонт анализа в неделях. Для этого найдем разницу в неделях между максимальной датой трансакций и датой начала акции то есть 01 июля 2015

# %%
horizon_weeks = int((data['transaction_date'].max() - pd.to_datetime('2015-07-01')).days / 7)
horizon_weeks
# Out:
# 20

# %% [markdown]
# Получили горизонт анализа 20 недель. Теперь сделаем срез данных, где максимальная когорта будет пользователями пришедшими в июле, а максимальный лайфтайм ограничен в 20 недель

# %%
retention = retention.loc[:'2015-07-01', :20]

# %% [markdown]
# Теперь рассчитаем Retention Rate для чего значения в колонках начиная с первой поделим на размеры когорт

# %%
retention = retention.iloc[::, 1:].div(retention['cohort_size'], axis=0)
retention
# Out:
# lifetime           1         2         3         4         5         6  \
# reg_month
# 2015-01-01  0.591837  0.312925  0.346939  0.374150  0.363946  0.326531
# 2015-02-01  0.477848  0.357595  0.344937  0.370253  0.322785  0.281646
# 2015-03-01  0.477901  0.292818  0.331492  0.314917  0.331492  0.306630
# 2015-04-01  0.451697  0.355091  0.305483  0.297650  0.300261  0.289817
# 2015-05-01  0.425197  0.375328  0.267717  0.257218  0.267717  0.259843
# 2015-06-01  0.496479  0.334507  0.292254  0.267606  0.260563  0.230634
# 2015-07-01  0.607143  0.529503  0.496894  0.439441  0.428571  0.385093
#
# lifetime           7         8         9        10        11        12  \
# reg_month
# 2015-01-01  0.421769  0.374150  0.346939  0.292517  0.336735  0.306122
# 2015-02-01  0.275316  0.335443  0.329114  0.313291  0.310127  0.243671
# 2015-03-01  0.243094  0.290055  0.229282  0.240331  0.232044  0.267956
# 2015-04-01  0.242820  0.287206  0.253264  0.219321  0.242820  0.240209
# ...

# %% [markdown]
# #### Построим тепловую карту

# %%
plt.figure(figsize=(20, 10))
sns.heatmap(retention, annot=True, cbar=False)
plt.title('Тепловая карта коэффициента удержания')
plt.yticks(ticks=range(1, 8), labels=range(1, 8))
plt.show()

# %% [markdown]
# - На графике видим, что пользователи зарегистрировавшиеся в июле - месяц проведения акции, на конец периода в 20 недель имеют самый маленький retention rate. Однако ранее на [графике динамики заказов](#orders_lineplot) мы видели очень резкое падение после достижения максимума в октябре.
# - Так как это падение может быть связано с техническими причинами, то будем смотреть retention до аномального падения то есть на 16-17 неделе лайфтайма
# - Но даже по лайфтайму на 16-17 неделе сказать, что проведенная акция помогла в удержании пользователей зарегистрировавшихся в июле нельзя

# %% [markdown]
# #### Посмотрим динамику изменения retention на линейном графике

# %%
retention.T.plot(figsize=(10, 7), color=['grey']*6+['red'])
plt.title('Динамика изменения Retention Rate по когортам')
plt.legend(retention.index.astype('str'))
plt.xticks(range(1, 21))
plt.show()

# %% [markdown]
# - Наша целевая когорта лидировала по коэффициенту удержания до 7 недели лайфтайма
# - Начиная с 17 недели лайфтайма идет резкое снижение коэффициента вплоть до самых низких показателей среди всех когорт, что мы выявили на предыдущем графике

# %% [markdown]
# ## Выводы
#
# - По результатам исследования можно предположить, что акция проведенная с целью улучшения Retention Rate не принесла положительных результатов.
# - Есть подозрения, что прсутствуют дополнительные причины, провала целевой когорты, связанные с приложением, так как на графиках мы видели очень резкие снижения заказов и регистрации новых пользователей начиная с октября 2015. Стоит узнать причины данных падений.
# - Для более корректных результатов стоит также сравнить retention между когортами зарегистрированных в июле 2015 и предыдущих годов (то есть за аналогичный период прошлых лет), но в исходных данных у нас отсутствуют наблюдения о заказах ранее 2015 года
